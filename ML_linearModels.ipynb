# %%
import sys
import sklearn
import tensorflow as tf
import torch
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# # Linear Regression

# %%
import numpy as np

np.random.seed(42)  # to make this code example reproducible
m = 100  # number of instances
X = 2 * np.random.rand(m, 1)  # column vector
y = 4 + 3 * X + np.random.randn(m, 1)  # column vector

# %%
plt.figure(figsize=(6, 4))
plt.plot(X, y, "ro")
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import add_dummy_feature

X_b = add_dummy_feature(X)  # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y
print(theta_best)
# Out:
# [[4.21509616]
#  [2.77011339]]

# %%
X_new = np.array([[0], [2]])
X_new_b = add_dummy_feature(X_new)  # add x0 = 1 to each instance
y_predict = X_new_b @ theta_best
y_predict
# Out:
# array([[4.21509616],
#        [9.75532293]])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(X_new, y_predict, "k-", label="Predictions") # creating the black line
plt.plot(X, y, "ro")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
print(lin_reg.intercept_, lin_reg.coef_)
print(lin_reg.predict(X_new)) #basically the same as above method
# Out:
# [4.21509616] [[2.77011339]]
# [[4.21509616]
#  [9.75532293]]

# %%
# other method to search for the linear models weight

theta_best_svd, residuals, rank, s = np.linalg.lstsq(X_b, y)
print(theta_best_svd)

theta = np.linalg.pinv(X_b) @ y
print(theta)
# Out:
# [[4.21509616]
#  [2.77011339]]
# [[4.21509616]
#  [2.77011339]]
# <ipython-input-42-9130e1288595>:3: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   theta_best_svd, residuals, rank, s = np.linalg.lstsq(X_b, y)
